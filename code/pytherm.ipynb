# %%
import pythermalcomfort

# %%
pythermalcomfort.models.utci(22, 11, 2.2, 62.5, units='SI', return_stress_category=False, limit_inputs=True)
# Out:
# 17.3

# %%
pythermalcomfort.models.pet_steady(25, 22, 2.2, 80.5, 1.37, 0.9, p_atm=1013.25, position=1, age=23, sex=1, weight=75, height=1.8, wme=0)
# Out:
# 23.36

# %%
import numpy as np
import matplotlib.pyplot as plt

# 평균과 표준편차
mu = 17.15
sigma = 1.43

# 정규 분포 데이터 생성
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(-(x - mu)**2 / (2 * sigma**2))

# 그래프 그리기
plt.plot(x, y, color='blue')
plt.title('Normal Distribution (mu=16.92, sigma=1.34)')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.show()

# 95% 신뢰구간 계산
import scipy.stats as stats
import math
