# %%
import matplotlib.pyplot as plt

# %%
version = "1.8"

# %%
data = {"train_result": [{"type": "train_loss", "epoch": 1, "value": 22638.292341280554}, {"type": "validation_loss", "epoch": 1, "value": 14294.816518801588}, {"type": "validation precision", "epoch": 1, "value": 0.11594202898550723}, {"type": "validation recall", "epoch": 1, "value": 0.09420289855072463}, {"type": "validataion f1_score", "epoch": 1, "value": 0.10351966873706005}, {"type": "train_loss", "epoch": 20, "value": 1929.4957825093843}, {"type": "validation_loss", "epoch": 20, "value": 1917.6892292820955}, {"type": "validation precision", "epoch": 20, "value": 0.14492753623188406}, {"type": "validation recall", "epoch": 20, "value": 0.0893719806763285}, {"type": "validataion f1_score", "epoch": 20, "value": 0.10766045548654245}, {"type": "train_loss", "epoch": 40, "value": 416.8958354003372}, {"type": "validation_loss", "epoch": 40, "value": 542.3581442615348}, {"type": "validation precision", "epoch": 40, "value": 0.15942028985507245}, {"type": "validation recall", "epoch": 40, "value": 0.10748792270531403}, {"type": "validataion f1_score", "epoch": 40, "value": 0.12298136645962732}, {"type": "train_loss", "epoch": 60, "value": 144.59122282714355}, {"type": "validation_loss", "epoch": 60, "value": 293.98131791780736}, {"type": "validation precision", "epoch": 60, "value": 0.1884057971014493}, {"type": "validation recall", "epoch": 60, "value": 0.13205659075224294}, {"type": "validataion f1_score", "epoch": 60, "value": 0.1497929606625259}, {"type": "train_loss", "epoch": 80, "value": 86.28411986292437}, {"type": "validation_loss", "epoch": 80, "value": 241.9148277633716}, {"type": "validation precision", "epoch": 80, "value": 0.17391304347826086}, {"type": "validation recall", "epoch": 80, "value": 0.11152518978605937}, {"type": "validataion f1_score", "epoch": 80, "value": 0.13012422360248446}, {"type": "train_loss", "epoch": 100, "value": 70.18373171471472}, {"type": "validation_loss", "epoch": 100, "value": 227.51466782385583}, {"type": "validation precision", "epoch": 100, "value": 0.1884057971014493}, {"type": "validation recall", "epoch": 100, "value": 0.1163561076604555}, {"type": "validataion f1_score", "epoch": 100, "value": 0.1373706004140787}, {"type": "train_loss", "epoch": 120, "value": 63.70877892968684}, {"type": "validation_loss", "epoch": 120, "value": 220.45600743925428}, {"type": "validation precision", "epoch": 120, "value": 0.15942028985507248}, {"type": "validation recall", "epoch": 120, "value": 0.10427881297446515}, {"type": "validataion f1_score", "epoch": 120, "value": 0.1204623878536922}, {"type": "train_loss", "epoch": 140, "value": 60.14492632625056}, {"type": "validation_loss", "epoch": 140, "value": 215.98121368637618}, {"type": "validation precision", "epoch": 140, "value": 0.15942028985507248}, {"type": "validation recall", "epoch": 140, "value": 0.10427881297446515}, {"type": "validataion f1_score", "epoch": 140, "value": 0.1204623878536922}, {"type": "train_loss", "epoch": 160, "value": 57.86754347461178}, {"type": "validation_loss", "epoch": 160, "value": 212.75549125546678}, {"type": "validation precision", "epoch": 160, "value": 0.15942028985507248}, {"type": "validation recall", "epoch": 160, "value": 0.10427881297446515}, {"type": "validataion f1_score", "epoch": 160, "value": 0.1204623878536922}, {"type": "train_loss", "epoch": 180, "value": 56.382140868510135}, {"type": "validation_loss", "epoch": 180, "value": 210.38538871665116}, {"type": "validation precision", "epoch": 180, "value": 0.15942028985507248}, {"type": "validation recall", "epoch": 180, "value": 0.10427881297446515}, {"type": "validataion f1_score", "epoch": 180, "value": 0.1204623878536922}, {"type": "train_loss", "epoch": 200, "value": 55.44784571567106}, {"type": "validation_loss", "epoch": 200, "value": 208.7331958179029}, {"type": "validation precision", "epoch": 200, "value": 0.17391304347826086}, {"type": "validation recall", "epoch": 200, "value": 0.11152518978605937}, {"type": "validataion f1_score", "epoch": 200, "value": 0.13012422360248446}], "data_count": 1338}

# %%
train_loss = [x for x in data["train_result"] if x["type"] == "train_loss"]
validation_loss = [x for x in data["train_result"] if x["type"] == "validation_loss"]
validation_precision = [x for x in data["train_result"] if x["type"] == "validation precision"]
validation_recall = [x for x in data["train_result"] if x["type"] == "validation recall"]
validation_f1_score = [x for x in data["train_result"] if x["type"] == "validataion f1_score"]

# %%
# 그래프 그리기
plt.figure(figsize=(10, 6))

plt.plot([x["epoch"] for x in train_loss], [x["value"] for x in train_loss], label='Train Loss')
plt.plot([x["epoch"] for x in validation_loss], [x["value"] for x in validation_loss], label='Validation Loss')

plt.title(f'Model version: {version}')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 1000)  # y축 범위 설정
plt.legend()
plt.show()

# %%
# 그래프 그리기
plt.figure(figsize=(10, 6))

plt.plot([x["epoch"] for x in validation_precision], [x["value"] for x in validation_precision], label='Validation Precision')
plt.plot([x["epoch"] for x in validation_recall], [x["value"] for x in validation_recall], label='Validation Recall')
plt.plot([x["epoch"] for x in validation_f1_score], [x["value"] for x in validation_f1_score], label='Validation F1 Score')

plt.title(f'Model version: {version}')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()
